# %%
import os
import csv
import pandas as pd
from ultralytics import YOLO
from dotenv import load_dotenv
import psycopg2
import torch  # Ensure you import torch

load_dotenv(r"C:\Users\hp\Desktop\medical-telegram-warehouse\medical-telegram-warehouse\.env")

# Allowlisting DetectionModel
torch.serialization.add_safe_globals([YOLO])

# DB connection parameters
conn_params = {
    'dbname': os.getenv('POSTGRES_DB'),
    # ... (fill similarly)
}

# Load YOLO model with weights_only set to False for loading
model = YOLO('yolov8n.pt')  # Nano model for efficiency
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[3], line 21
#      15 conn_params = {
#      16     'dbname': os.getenv('POSTGRES_DB'),
#      17     # ... (fill similarly)
#      18 }
#      20 # Load YOLO model with weights_only set to False for loading
# ---> 21 model = YOLO('yolov8n.pt')  # Nano model for efficiency
#
# File c:\Users\hp\Desktop\medical-telegram-warehouse\medical-telegram-warehouse\venv\Lib\site-packages\ultralytics\engine\model.py:95, in Model.__init__(self, model, task)
#      93     self._new(model, task)
#      94 else:
# ---> 95     self._load(model, task)
#      97 self.model_name = model
#
# File c:\Users\hp\Desktop\medical-telegram-warehouse\medical-telegram-warehouse\venv\Lib\site-packages\ultralytics\engine\model.py:161, in Model._load(self, weights, task)
#     159 suffix = Path(weights).suffix
#     160 if suffix == ".pt":
# ...
